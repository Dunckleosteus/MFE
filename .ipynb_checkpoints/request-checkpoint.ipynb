# %% [markdown]
# ## Querying data
#
# We need to get ID's so that we may install relevant data
# ### Converting geojson to wkt
# It needs to be in a specific format for it to work in the query

# %%
import geopandas as gpd
import os
#json_path = r"/home/throgg/Downloads/test_road/test_road.geojson"
json_path = os.path.join("sections_mfe", "buffers", "A43_33_44.geojson")
gdf = gpd.read_file(json_path)
gdf.crs = 'EPSG:4326'
gdf_exploded = gdf.explode(index_parts=True)

# Keep only the first geometry for each feature
gdf_first_geometry = gdf_exploded.groupby(level=0).first()
first_geometry_wkt = gdf_first_geometry.geometry.iloc[0].wkt

gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56b4f1ed88168a7920df121e01cfad08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56b4f1ed88168a7920df121e01cfad08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56b4f1ed88168a7920df121e01cfad08 = L.map(
#                 &quot;map_56b4f1ed88168a7920df121e01cfad08&quot;,
#                 {
#                     center: [45.582790356001, 5.315503918424018],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_56b4f1ed88168a7920df121e01cfad08);
#
#
#
#
#
#             var tile_layer_9d9a63ca764fb7dbc2cfef2ab188a0d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_56b4f1ed88168a7920df121e01cfad08);
#
#
#             map_56b4f1ed88168a7920df121e01cfad08.fitBounds(
#                 [[45.561999749717145, 5.256018566739281], [45.60358096228486, 5.374989270108755]],
#                 {}
#             );
#
#
#         function geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_f5e1f2035c70d4d59594fa5a9649c5a7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f5e1f2035c70d4d59594fa5a9649c5a7 = L.geoJson(null, {
#                 onEachFeature: geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_onEachFeature,
#
#                 style: geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_styler,
#                 pointToLayer: geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_pointToLayer
#         });
#
#         function geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_add (data) {
#             geo_json_f5e1f2035c70d4d59594fa5a9649c5a7
#                 .addData(data)
#                 .addTo(map_56b4f1ed88168a7920df121e01cfad08);
#         }
#             geo_json_f5e1f2035c70d4d59594fa5a9649c5a7_add({&quot;bbox&quot;: [5.256018566739281, 45.561999749717145, 5.374989270108755, 45.60358096228486], &quot;features&quot;: [{&quot;bbox&quot;: [5.256018566739281, 45.561999749717145, 5.374989270108755, 45.60358096228486], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[5.256018566739281, 45.60328671462783], [5.25608161980865, 45.60358096228486], [5.257323280251573, 45.60332632488937], [5.25854230625934, 45.60308057959336], [5.258928708402387, 45.603032077232314], [5.259389480832378, 45.60293992274634], [5.259675644762583, 45.602888186894525], [5.261717506499203, 45.60244673283748], [5.264005482538052, 45.601987215386764], [5.2642655848

# %% [markdown]
# ### Query using geospatial data
#
# Note that we are also querying by collection, in this case `SENTINEL-2`

# %%
import requests
import pandas as pd
# Define the URL with the query parameters
url = "https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=OData.CSC.Intersects(area=geography'SRID=4326;{}') and Collection/Name eq 'SENTINEL-2' and ContentDate/Start gt 2015-01-01T00:00:00.000Z and ContentDate/Start lt 2022-06-01T00:00:00.000Z and Attributes/OData.CSC.DoubleAttribute/any(att:att/Name eq 'cloudCover' and att/OData.CSC.DoubleAttribute/Value lt 20.00)".format(first_geometry_wkt)

# Make the GET request
response = requests.get(url).json()
df = pd.DataFrame.from_dict(response['value'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 8
#       6 # Make the GET request
#       7 response = requests.get(url).json()
# ----> 8 df = pd.DataFrame.from_dict(response['value'])
#       9 df
#
# KeyError: 'value'

# %% [markdown]
# ## Double checking geometries
# Some of the data returned does not actually overlap our our geometries properly

# %%
## Todo add a second geometry filter

# %% [markdown]
# ## Getting access tokens
# This token is needed to install data

# %%
import requests

# Define the endpoint and payload
url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
payload = {
    "username": "ghus266@gmail.com",
    "password": "LL@nb@d0c2ooo",
    "grant_type": "password",
    "client_id": "cdse-public"
}

# Make the HTTP POST request
response = requests.post(url, data=payload, headers={"Content-Type": "application/x-www-form-urlencoded"})


data = response.json()
access_token = data.get("access_token")
print(access_token)
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJYVUh3VWZKaHVDVWo0X3k4ZF8xM0hxWXBYMFdwdDd2anhob2FPLUxzREZFIn0.....cML8YBLUZboQme3SKGKofD2JsE8u33lKXfOUC9XTyHzn1XIKfz7qE3PwqjHJaaN0u6wsFFJ4mIRDdCMQSttpOwvgP0eY3d89mKkh5uORtR-Yi6IMX_ARJsDUjTEYD0ac8MwFuuDAfPoMx25P7fRk5kncIHU0ki2YT7DRmTsMLY8Hhhev6AMO1JFbDdryV1YZ9dUzGNlEk_mpwySJwgzN90wU43mA6114t9PxHuV7gV1B5GAgIb60orYbpFJlYa1qAv6ZvhysW0US8-Jc42GEzbMtJPZC312mBd4F25nE91ZB6vjucy6X6Pl8NSmsYX1lLIHAjwupgMEmGuhqgI6wyA

# %% [markdown]
# # Downloading data
#
# Now that we have ID selected using geographical data and access tokens we can procceed to the installation

# %%
output_file_location = "product.zip"
import shutil
# delete existing files
try:
    os.remove(output_file_location)
except:
    print("{} does not exist, moving on".format(output_file_location))

try: 
    sisi_path = os.path.join(os.getcwd(), "sisi")
    shutil.rmtree(sisi_path)
except: 
    print("Sisi file does not exist, moving on")
# Out:
# product.zip does not exist, moving on
# Sisi file does not exist, moving on

# %%
import requests
import tqdm
myid = df.loc[1, "Id"]
url = f"https://zipper.dataspace.copernicus.eu/odata/v1/Products({myid})/$value"

headers = {"Authorization": f"Bearer {access_token}"}

session = requests.Session()
session.headers.update(headers)
response = session.get(url, headers=headers, stream=True)


with open(output_file_location, "wb") as file:
    for chunk in tqdm.tqdm(response.iter_content(chunk_size=8192)):
        if chunk:
            file.write(chunk)
# Out:
# 92029it [01:30, 1016.45it/s]

# %% [markdown]
# # Opening data
# Because only a small part of the data is interesting, we need to trim the images to only keep the pixels that are under our mask. This will allow us to save place

# %%
# we start by unzipping the file
import zipfile
path_to_unzipped_file = "sisi"
with zipfile.ZipFile(output_file_location, 'r') as zip_ref:
    zip_ref.extractall(path_to_unzipped_file)

# %%
import osgeo
import rasterio as rio
import matplotlib.pyplot as plt
import numpy as np

# now navigate and open the raster file
import glob
# making list of image files
l = glob.glob("sisi/*/GRANULE/*/IMG_DATA/*")
l.sort()
print(l)
# Out:
# ['sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B01.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B02.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B03.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B04.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B05.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B06.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B07.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B08.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B09.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B10.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B11.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B12.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_B8A.jp2', 'sisi/S2B_MSIL1C_20220118T110259_N0301_R094_T31UCR_20220118T115412.SAFE/GRANULE/L1C_T31UCR_A025431_20220118T110424/IMG_DATA/T31UCR_20220118T110259_TCI.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B01.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B02.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B03.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B04.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B05.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B06.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B07.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B08.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B09.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B10.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GRANULE/L1C_T30UYA_A027290_20220528T105912/IMG_DATA/T30UYA_20220528T105619_B11.jp2', 'sisi/S2B_MSIL1C_20220528T105619_N0400_R094_T30UYA_20220528T114625.SAFE/GR ...

# %%
import geopandas as gpd
gdf = gpd.read_file(json_path)
gdf=gdf.to_crs("EPSG:32631")

#gdf.explore()

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots()
src = rio.open(l[6])
extent = [src.bounds[0], src.bounds[2], src.bounds[1], src.bounds[3]]
#extent = [src.bounds[1], src.bounds[3], src.bounds[0], src.bounds[2]]
# axs = rio.plot.show(src.read(1), extent=extent, cmap='viridis')
plt.imshow(src.read(1), extent=extent)

print(src.crs)
gdf.plot(ax=axs)
# ax
plt.show()
# Out:
# EPSG:32631

# %% [markdown]
# # Snipping raster by mask

# %%
# looping through the images
srcs = []
extents = []
for selection in l[2:3]:
    src = rio.open(
	    selection
	)
    srcs.append(src)
    extents.append(
	    [src.bounds[0], src.bounds[2], src.bounds[1], src.bounds[3]]
	)

# %%
from rasterio import mask
clipped_bands = []
for num, src in enumerate(srcs): 
    out_image, out_transform = rio.mask.mask(
	    src, 
	    gdf.geometry, 
	    crop=True
	)
    clipped_bands.append(np.squeeze(out_image))
clipped_stacked = np.stack(clipped_bands, axis=0)
plt.imshow(clipped_stacked[0, :, :])

# %%
import os
from glob import glob
import matplotlib.pyplot as plt
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 4
#       2 from glob import glob
#       3 import matplotlib.pyplot as plt
# ----> 4 import earthpy as et
#       5 import earthpy.spatial as es
#       6 import earthpy.plot as ep
#
# ModuleNotFoundError: No module named 'earthpy'

# %%
gdf.plot()
